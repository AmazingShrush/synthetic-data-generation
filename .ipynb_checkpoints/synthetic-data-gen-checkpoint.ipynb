# %%
import sdv
print(sdv.__version__)
import pandas as pd
import commonfunc as common
import numpy as np
# Out:
# 1.2.1

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
from sdv.datasets.local import load_csvs
from sdv.datasets.demo import download_demo

# This is the default folder name that the GOogle Colab notebook uses.
# Change this if you have your own folder with CSV files.
FOLDER_NAME = 'sampled_data_csv_100/'

try:
  datasets = load_csvs(folder_name='C:\\Users\\shrus\\Documents\\Synthetic-data-generation\\sampled_data_csv_100\\')
except ValueError:
  print('You have not uploaded any csv files. Using some demo data instead.')
  datasets, _ = download_demo(
    modality='multi_table',
    dataset_name='fake_hotels'
  )

# %%
admissions_df=datasets['admissions']
callout_df=datasets['callout']
chartevents_df=datasets['chartevents']
cptevents_df = datasets['cptevents']
icustays_df = datasets['icustays']
inputevents_mv_df = datasets['inputevents_mv']
labevents_df = datasets['labevents']
microbiologyevents_df = datasets['microbiologyevents']
outputevents_df = datasets['outputevents']
patients_df = datasets['patients']
prescriptions_df = datasets['prescriptions']
procedureevents_mv_df = datasets['procedureevents_mv']
procedures_icd_df = datasets['procedures_icd']

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Dropping row_id column

# %%
def drop_row_id_column(data):
    if 'row_id' in data.columns:
        data.drop('row_id', axis=1, inplace=True)

# %%
drop_row_id_column(admissions_df)
drop_row_id_column(callout_df)
drop_row_id_column(chartevents_df)
drop_row_id_column(cptevents_df)
drop_row_id_column(icustays_df)
drop_row_id_column(inputevents_mv_df)
drop_row_id_column(labevents_df)
drop_row_id_column(microbiologyevents_df)
drop_row_id_column(outputevents_df)
drop_row_id_column(patients_df)
drop_row_id_column(prescriptions_df)
drop_row_id_column(procedureevents_mv_df)
drop_row_id_column(procedures_icd_df)

# %% [markdown]
# ## Handling Date and time objects

# %%
def changeObjectToDateTime(df,list):
    for i in list:
        df[i]=pd.to_datetime(df[i])

# %%
changeObjectToDateTime(admissions_df,['admittime','dischtime','deathtime','edregtime','edouttime'])
changeObjectToDateTime(callout_df,['createtime','updatetime','acknowledgetime','outcometime','firstreservationtime','currentreservationtime'])
changeObjectToDateTime(chartevents_df,['charttime','storetime'])
changeObjectToDateTime(icustays_df,['intime','outtime'])
changeObjectToDateTime(inputevents_mv_df,['starttime','endtime','storetime','comments_date'])
changeObjectToDateTime(labevents_df,['charttime'])
changeObjectToDateTime(microbiologyevents_df,['chartdate','charttime'])
changeObjectToDateTime(outputevents_df,['charttime','storetime'])
changeObjectToDateTime(patients_df,['dob','dod','dod_hosp','dod_ssn'])
changeObjectToDateTime(prescriptions_df,['startdate','enddate'])
changeObjectToDateTime(procedureevents_mv_df,['starttime','endtime','storetime','comments_date'])

# %% [markdown]
# ## Preprocessing individual tables

# %% [markdown]
# ### Patients table:

# %%
patients_df.head()
# Out:
#    subject_id gender        dob        dod   dod_hosp    dod_ssn  expire_flag
# 0       87197      F 2054-10-12        NaT        NaT        NaT            0
# 1        1765      M 2183-05-09        NaT        NaT        NaT            0
# 2       21269      M 2078-07-25 2162-12-10 2162-12-10 2162-12-10            1
# 3        5692      M 2099-09-01        NaT        NaT        NaT            0
# 4       30096      F 2080-05-03 2161-10-08        NaT 2161-10-08            1

# %%
admission_date = admissions_df.loc[:, ['subject_id', 'admittime']]
patients_mid = pd.merge(left=patients_df, right=admission_date, how='inner', on=['subject_id'])

# %%
patients_mid
# Out:
#      subject_id gender        dob        dod   dod_hosp    dod_ssn  \
# 0         87197      F 2054-10-12        NaT        NaT        NaT
# 1          1765      M 2183-05-09        NaT        NaT        NaT
# 2         21269      M 2078-07-25 2162-12-10 2162-12-10 2162-12-10
# 3          5692      M 2099-09-01        NaT        NaT        NaT
# 4          5692      M 2099-09-01        NaT        NaT        NaT
# ..          ...    ...        ...        ...        ...        ...
# 127       58667      M 2067-06-29 2130-08-20 2130-08-20 2130-08-20
# 128        3391      F 2143-03-01        NaT        NaT        NaT
# 129       31650      M 2090-11-19        NaT        NaT        NaT
# 130       15895      M 2039-10-21 2124-07-11        NaT 2124-07-11
# 131       52058      M 2077-10-25        NaT        NaT        NaT
#
#      expire_flag           admittime
# 0              0 2109-11-16 08:11:00
# 1              0 2183-05-09 08:35:00
# 2              1 2162-10-03 17:02:00
# 3              0 2143-10-23 15:42:00
# 4              0 2147-12-15 23:57:00
# ..           ...                 ...
# 127            1 2130-08-19 20:03:00
# 128            0 2143-03-01 19:47:00
# 129            0 2177-06-07 17:54:00
# 130            1 2116-07-04 17:13:00
# 131            0 2121-11-22 13:53:00
#
# [132 rows x 8 columns]

# %%
admission_date.drop_duplicates(subset=['subject_id'], keep='first', inplace=True)

# %%
admission_date
# Out:
#      subject_id           admittime
# 0         87197 2109-11-16 08:11:00
# 1          1765 2183-05-09 08:35:00
# 2         21269 2162-10-03 17:02:00
# 3          5692 2143-10-23 15:42:00
# 6         30096 2161-08-27 15:11:00
# ..          ...                 ...
# 127       58667 2130-08-19 20:03:00
# 128        3391 2143-03-01 19:47:00
# 129       31650 2177-06-07 17:54:00
# 130       15895 2116-07-04 17:13:00
# 131       52058 2121-11-22 13:53:00
#
# [100 rows x 2 columns]

# %%
# Drop useless colums
patients_df.drop(['expire_flag', 'dod'], axis=1, inplace=True)

# %%
patients_df.isnull().sum()
# Out:
# subject_id     0
# gender         0
# dob            0
# dod_hosp      80
# dod_ssn       75
# dtype: int64

# %%
patients_df.dtypes
# Out:
# subject_id             int64
# gender                object
# dob           datetime64[ns]
# dod_hosp      datetime64[ns]
# dod_ssn       datetime64[ns]
# dtype: object

# %%
patients_df = pd.merge(left=patients_df, right=admission_date, how='inner', on=['subject_id'])

# %%
import datetime
import random

def adjust_age_over_90(df):
    years_100 = datetime.timedelta(days = (365 * 100 + 100/4))
    random_days_10_years = datetime.timedelta(days = random.randint(0, 10)*365)
    
    if (df['dob'] - datetime.datetime(1970,1,1)).total_seconds() < 0:
        return (df['admittime'] - years_100 + random_days_10_years)
    else:
        return df['dob']

# %%
patients_df['dob'] = patients_df.apply(adjust_age_over_90, axis=1)

# %%
# Calculate the age
def get_birth_delta(df):
    return df['admittime'] - df['dob']

# Randomly pick a time between 2001-2012
def adjust_admittime(df):
    return pd.Timestamp(year=random.randint(2001, 2012), \
        month=df['admittime'].month, day=df['admittime'].day)

# Renew the date of birth
def reset_dob(df):
    dob = df['admittime'] - df['dob']
    return pd.to_datetime(dob.date())

# %%
patients_df['dob'] = patients_df.apply(get_birth_delta, axis=1)
patients_df['admittime'] = patients_df.apply(adjust_admittime, axis=1)
patients_df['dob'] = patients_df.apply(reset_dob, axis=1)

# %%
patients_df
# Out:
#     subject_id gender        dob   dod_hosp    dod_ssn  admittime
# 0        87197      F 1954-10-12        NaT        NaT 2009-11-16
# 1         1765      M 2008-05-08        NaT        NaT 2008-05-09
# 2        21269      M 1919-07-25 2162-12-10 2162-12-10 2003-10-03
# 3         5692      M 1959-09-01        NaT        NaT 2003-10-23
# 4        30096      F 1923-05-04        NaT 2161-10-08 2004-08-27
# ..         ...    ...        ...        ...        ...        ...
# 95       58667      M 1949-06-29 2130-08-20 2130-08-20 2012-08-19
# 96        3391      F 2001-02-28        NaT        NaT 2001-03-01
# 97       31650      M 1918-11-19        NaT        NaT 2005-06-07
# 98       15895      M 1932-10-20        NaT 2124-07-11 2009-07-04
# 99       52058      M 1967-10-25        NaT        NaT 2011-11-22
#
# [100 rows x 6 columns]

# %%
patients_df.drop(['admittime'], axis=1, inplace=True)

# %% [markdown]
# ### Admissions Table

# %%
admissions_df.head()
# Out:
#    subject_id  hadm_id           admittime           dischtime deathtime  \
# 0       87197   176931 2109-11-16 08:11:00 2109-11-18 17:25:00       NaT
# 1        1765   145878 2183-05-09 08:35:00 2183-05-16 11:50:00       NaT
# 2       21269   109697 2162-10-03 17:02:00 2162-12-01 19:30:00       NaT
# 3        5692   151113 2143-10-23 15:42:00 2143-11-08 17:25:00       NaT
# 4        5692   193147 2147-12-15 23:57:00 2147-12-27 12:00:00       NaT
#
#   admission_type         admission_location   discharge_location insurance  \
# 0      EMERGENCY       EMERGENCY ROOM ADMIT                 HOME   Private
# 1        NEWBORN  PHYS REFERRAL/NORMAL DELI                 HOME   Private
# 2      EMERGENCY       EMERGENCY ROOM ADMIT  SHORT TERM HOSPITAL  Medicare
# 3      EMERGENCY  PHYS REFERRAL/NORMAL DELI     HOME HEALTH CARE   Private
# 4      EMERGENCY  TRANSFER FROM HOSP/EXTRAM                 HOME   Private
#
#   language       religion marital_status ethnicity           edregtime  \
# 0     ENGL  NOT SPECIFIED        MARRIED     WHITE 2109-11-16 01:09:00
# 1      NaN   UNOBTAINABLE            NaN     WHITE                 NaT
# 2      NaN         JEWISH        MARRIED     WHITE 2162-10-03 09:24:00
# 3     ENGL  NOT SPECIFIED        MARRIED     WHITE                 NaT
# 4     ENGL  NOT SPECIFIED        MARRIED     WHITE                 NaT
#
#             edouttime                diagnosis  hospital_expire_flag  \
# 0 2109-11-16 09:26:00    ALTERED MENTAL STATUS                     0
# 1                 NaT                  NEWBORN                     0
# 2 2162-10-03 17:18:00                PNEUMONIA                     0
# 3                 NaT  CORONARY ARTERY DISEASE                     0
# 4                 NaT     IRREGULAR HEART RATE                     0
#
#    has_chartevents_data
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
admissions_df.drop(['diagnosis', 'hospital_expire_flag'], axis=1, inplace=True)

# %%
dob_df = patients_df.loc[:, ['subject_id', 'dob']]

# %%
admissions_df = pd.merge(dob_df, admissions_df, how='inner', on='subject_id')

# %%
admissions_df.isnull().sum()
# Out:
# subject_id                0
# dob                       0
# hadm_id                   0
# admittime                 0
# dischtime                 0
# deathtime               121
# admission_type            0
# admission_location        0
# discharge_location        0
# insurance                 0
# language                 45
# religion                  1
# marital_status           19
# ethnicity                 0
# edregtime                62
# edouttime                62
# has_chartevents_data      0
# dtype: int64

# %%
admissions_df.dtypes
# Out:
# subject_id                       int64
# dob                     datetime64[ns]
# hadm_id                          int64
# admittime               datetime64[ns]
# dischtime               datetime64[ns]
# deathtime               datetime64[ns]
# admission_type                  object
# admission_location              object
# discharge_location              object
# insurance                       object
# language                        object
# religion                        object
# marital_status                  object
# ethnicity                       object
# edregtime               datetime64[ns]
# edouttime               datetime64[ns]
# has_chartevents_data             int64
# dtype: object

# %%
(admissions_df['dob'] < admissions_df['admittime']).value_counts()
# Out:
# True    132
# dtype: int64

# %%
admissions_df = admissions_df.drop(admissions_df.loc[(pd.isna(admissions_df['deathtime']) == False) & (admissions_df['dischtime'] != admissions_df['deathtime'])].index)

# %%
import datetime
import random

def adjust_age_over_90(df):
    '''
    This method is to adjust the invalid date in 'dob' (which is 18xx)
    Process: Use the admittime minus 90 - 100 years, to let the age of patients are between 90 to 100
    '''

    years_100 = datetime.timedelta(days = (365 * 100 + 100/4))
    random_days_10_years = datetime.timedelta(days = random.randint(0, 10)*365)
    
    if (df['dob'] - datetime.datetime(1970,1,1)).total_seconds() < 0:
        return (df['admittime'] - years_100 + random_days_10_years)
    else:
        return df['dob']

# %%
admissions_df['dob'] = admissions_df.apply(adjust_age_over_90, axis=1)

# %%
admissions_df['deathtime'] = admissions_df['deathtime'].apply(lambda flag: 1 if pd.isna(flag) == False else np.NaN)

# %%
# admissions_df['edouttime'] = admissions_df.apply(common.time_process, args=('edregtime', 'edouttime'), axis=1)
# admissions_df['edregtime'] = admissions_df.apply(common.time_process, args=('admittime', 'edregtime'), axis=1)
# admissions_df['dischtime'] = admissions_df.apply(common.time_process, args=('admittime', 'dischtime'), axis=1)
# admissions_df['admittime'] = admissions_df.apply(common.time_process, args=('dob', 'admittime'), axis=1)

# %%
admissions_df.drop(['dob'], axis=1, inplace=True)

# %%
admissions_df
# Out:
#      subject_id  hadm_id           admittime           dischtime  deathtime  \
# 0         87197   176931 2109-11-16 08:11:00 2109-11-18 17:25:00        NaN
# 1          1765   145878 2183-05-09 08:35:00 2183-05-16 11:50:00        NaN
# 2         21269   109697 2162-10-03 17:02:00 2162-12-01 19:30:00        NaN
# 3          5692   151113 2143-10-23 15:42:00 2143-11-08 17:25:00        NaN
# 4          5692   193147 2147-12-15 23:57:00 2147-12-27 12:00:00        NaN
# ..          ...      ...                 ...                 ...        ...
# 127       58667   197356 2130-08-19 20:03:00 2130-08-20 01:56:00        1.0
# 128        3391   136471 2143-03-01 19:47:00 2143-03-03 15:11:00        NaN
# 129       31650   137933 2177-06-07 17:54:00 2177-06-12 14:34:00        NaN
# 130       15895   135286 2116-07-04 17:13:00 2116-07-14 12:16:00        NaN
# 131       52058   146270 2121-11-22 13:53:00 2121-11-24 19:46:00        NaN
#
#     admission_type         admission_location   discharge_location  \
# 0        EMERGENCY       EMERGENCY ROOM ADMIT                 HOME
# 1          NEWBORN  PHYS REFERRAL/NORMAL DELI                 HOME
# 2        EMERGENCY       EMERGENCY ROOM ADMIT  SHORT TERM HOSPITAL
# 3        EMERGENCY  PHYS REFERRAL/NORMAL DELI     HOME HEALTH CARE
# 4        EMERGENCY  TRANSFER FROM HOSP/EXTRAM                 HOME
# ..             ...                        ...                  ...
# 127      EMERGENCY  CLINIC REFERRAL/PREMATURE         DEAD/EXPIRED
# 128        NEWBORN  CLINIC REFERRAL/PREMATURE                 HOME
# 129      EMERGENCY  TRANSFER FROM HOSP/EXTRAM                  SNF
# 130      EMERGENCY       EMERGENCY ROOM ADMIT                  SNF
# 131         URGENT  PHYS REFERRAL/NORMAL DELI                 HOME
#
#       insurance language           religion marital_status  \
# 0       Private     ENGL      NOT SPECIFIED        MARRIED
# 1       Private      NaN       UNOBTAINABLE            NaN
# 2      Medicare      NaN             JEWISH        MARRIED
# 3       Private     ENGL      NOT SPECIFIED        MARRIED
# 4       Private     ENGL      NOT SPECIFIED        MARRIED
# ..          ...      ...                ...            ...
# 127  Government     ENGL  PROTESTANT QUAKER       DIVORCED
# 128    Medicaid      NaN       UNOBTAINABLE            NaN
# 129    Medicare      NaN           CATHOLIC        MARRIED
# 130    Medicare      NaN  PROTESTANT QUAKER        MARRIED
# 131     Private     ENGL      NOT SPECIFIED         SINGLE
#
#                       ethnicity           edregtime           edouttime  \
# 0                         WHITE 2109-11-16 01:09:00 2109-11-16 09:26:00
# 1                         WHITE                 NaT                 NaT
# 2                         WHITE 2162-10-03 09:24:00 2162-10-03 17:18:00
# 3                         WHITE                 NaT                 NaT
# 4                         WHITE                 NaT                 NaT
# ..                          ...                 ...                 ...
# 127                       WHITE 2130-08-19 15:57:00 2130-08-19 21:16:00
# 128      BLACK/AFRICAN AMERICAN                 NaT                 NaT
# 129            UNABLE TO OBTAIN                 NaT                 NaT
# 130       UNKNOWN/NOT SPECIFIED                 NaT                 NaT
# 131  PATIENT DECLINED TO ANSWER                 NaT                 NaT
#
#      has_chartevents_data
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ..                    ...
# 127                     1
# 128                     1
# 129                     1
# 130                     1
# 131                     1
#
# [132 rows x 16 columns]

# %% [markdown]
# ### Icustays table:

# %%
icustays_df.head()
# Out:
#    subject_id  hadm_id  icustay_id    dbsource first_careunit last_careunit  \
# 0       87197   176931      209341  metavision            CCU           CCU
# 1        1765   145878      254146     carevue           NICU          NICU
# 2       21269   109697      241691     carevue           MICU          MICU
# 3        5692   151113      279055     carevue           CSRU          CSRU
# 4        5692   193147      241135  metavision            CCU           CCU
#
#    first_wardid  last_wardid              intime             outtime      los
# 0             7            7 2109-11-16 08:12:18 2109-11-17 17:39:41   1.3940
# 1            56           56 2183-05-09 09:29:55 2183-05-16 19:18:28   7.4087
# 2            12           12 2162-10-03 17:03:08 2162-12-01 20:11:22  59.1307
# 3            12           15 2143-10-31 14:16:32 2143-11-01 19:20:00   1.2107
# 4             7            7 2147-12-16 00:00:03 2147-12-17 16:45:54   1.6985

# %%
icustays_df.isnull().sum()
# Out:
# subject_id        0
# hadm_id           0
# icustay_id        0
# dbsource          0
# first_careunit    0
# last_careunit     0
# first_wardid      0
# last_wardid       0
# intime            0
# outtime           0
# los               0
# dtype: int64

# %%
admission_mid = admissions_df.loc[:, ['hadm_id', 'admittime']]

# %%
icustays_mid_df = pd.merge(left=icustays_df, right=admission_mid , how='left', on=['hadm_id'])

# %%
# icustays_mid_df['outtime'] = icustays_mid_df.apply(common.time_process, args=('intime', 'outtime'), axis=1)
# icustays_mid_df['intime'] = icustays_mid_df.apply(common.time_process, args=('admittime', 'intime'), axis=1)

# %%
icustays_df = icustays_mid_df.drop([ 'admittime'], axis=1)

# %%
icustays_df
# Out:
#      subject_id  hadm_id  icustay_id    dbsource first_careunit last_careunit  \
# 0         87197   176931      209341  metavision            CCU           CCU
# 1          1765   145878      254146     carevue           NICU          NICU
# 2         21269   109697      241691     carevue           MICU          MICU
# 3          5692   151113      279055     carevue           CSRU          CSRU
# 4          5692   193147      241135  metavision            CCU           CCU
# ..          ...      ...         ...         ...            ...           ...
# 133       58667   197356      249803  metavision           MICU          MICU
# 134        3391   136471      265244     carevue           NICU          NICU
# 135       31650   137933      282691     carevue            CCU           CCU
# 136       15895   135286      236445     carevue           CSRU          CSRU
# 137       52058   146270      292639  metavision           SICU          SICU
#
#      first_wardid  last_wardid              intime             outtime  \
# 0               7            7 2109-11-16 08:12:18 2109-11-17 17:39:41
# 1              56           56 2183-05-09 09:29:55 2183-05-16 19:18:28
# 2              12           12 2162-10-03 17:03:08 2162-12-01 20:11:22
# 3              12           15 2143-10-31 14:16:32 2143-11-01 19:20:00
# 4               7            7 2147-12-16 00:00:03 2147-12-17 16:45:54
# ..            ...          ...                 ...                 ...
# 133            50           50 2130-08-19 20:03:38 2130-08-20 07:17:43
# 134            56           56 2143-03-01 19:51:18 2143-03-01 23:53:41
# 135             7            7 2177-06-07 19:44:18 2177-06-10 15:45:28
# 136            14           14 2116-07-06 10:36:00 2116-07-07 21:28:00
# 137            33           33 2121-11-23 19:12:03 2121-11-24 00:38:42
#
#          los
# 0     1.3940
# 1     7.4087
# 2    59.1307
# 3     1.2107
# 4     1.6985
# ..       ...
# 133   0.4681
# 134   0.1683
# 135   2.8341
# 136   1.4528
# 137   0.2268
#
# [138 rows x 11 columns]

# %% [markdown]
# ### Preparing data to be fed in the model

# %%
datasets['admissions']=admissions_df
datasets['callout']=callout_df
datasets['chartevents']=chartevents_df
datasets['cptevents']=cptevents_df 
datasets['icustays']=icustays_df 
datasets['inputevents_mv']=inputevents_mv_df 
datasets['labevents']=labevents_df 
datasets['microbiologyevents']=microbiologyevents_df 
datasets['outputevents']=outputevents_df 
datasets['patients']=patients_df 
datasets['prescriptions']=prescriptions_df 
datasets['procedureevents_mv']=procedureevents_mv_df 
datasets['procedures_icd']=procedures_icd_df

# %%
dataTest={
    'admissions': admissions_df,
    'patients':patients_df,
    'icustays':icustays_df
}

# %% [markdown]
# ## Metadata

# %%
from sdv.metadata import MultiTableMetadata

metadata = MultiTableMetadata()

# %%
metadata.detect_table_from_dataframe(
    table_name='admissions',
    data=admissions_df
)
metadata.detect_table_from_dataframe(
    table_name='patients',
    data=patients_df
)

metadata.detect_table_from_dataframe(
    table_name='icustays',
    data=icustays_df
)
# Out:
# ---------------------------------------------------------------------------
# InvalidMetadataError                      Traceback (most recent call last)
# Cell In[256], line 1
# ----> 1 metadata.detect_table_from_dataframe(
#       2     table_name='admissions',
#       3     data=admissions_df
#       4 )
#       5 metadata.detect_table_from_dataframe(
#       6     table_name='patients',
#       7     data=patients_df
#       8 )
#      10 metadata.detect_table_from_dataframe(
#      11     table_name='icustays',
#      12     data=icustays_df
#      13 )
#
# File ~\anaconda3\lib\site-packages\sdv\metadata\multi_table.py:340, in MultiTableMetadata.detect_table_from_dataframe(self, table_name, data)
#     331 def detect_table_from_dataframe(self, table_name, data):
#     332     """Detect the metadata for a table from a dataframe.
#     333
#     334     Args:
#    (...)
#     338             ``pandas.DataFrame`` to detect the metadata from.
#     339     """
# --> 340     self._validate_table_not_detected(table_name)
#     341     table = SingleTableMetadata()
#     342     table._detect_columns(data)
#
# File ~\anaconda3\lib\site-packages\sdv\metadata\multi_table.py:319, in MultiTableMetadata._validate_table_not_detected(self, table_name)
#     317 def _validate_table_not_detected(self, table_name):
#     318     if table_name in self.tables:
# --> 319         raise InvalidMetadataError(
#     320             f"Metadata for table '{table_name}' already exists. Specify a new table name or "
#     321             'create a new MultiTableMetadata object for other data sources.'
#     322         )
#
# InvalidMetadataError: Metadata for table 'admissions' already exists. Specify a new table name or create a new MultiTableMetadata object for other data sources.

# %%
print('Auto detected data:\n')
metadata
# Out:
# Auto detected data:
# {
#     "tables": {
#         "admissions": {
#             "columns": {
#                 "subject_id": {
#                     "sdtype": "numerical"
#                 },
#                 "hadm_id": {
#                     "sdtype": "numerical"
#                 },
#                 "admittime": {
#                     "sdtype": "datetime"
#                 },
#                 "dischtime": {
#                     "sdtype": "datetime"
#                 },
#                 "deathtime": {
#                     "sdtype": "numerical"
#                 },
#                 "admission_type": {
#                     "sdtype": "categorical"
#                 },
#                 "admission_location": {
#                     "sdtype": "categorical"
#                 },
#                 "discharge_location": {
#                     "sdtype": "categorical"
#                 },
#                 "insurance": {
#                     "sdtype": "categorical"
#                 },
#                 "language": {
#                     "sdtype": "categorical"
#                 },
#                 "religion": {
#                     "sdtype": "categorical"
#                 },
#                 "marital_status": {
#                     "sdtype": "categorical"
#                 },
#                 "ethnicity": {
#                     "sdtype": "categorical"
#                 },
#                 "edregtime": {
#                     "sdtype": "datetime"
#                 },
#                 "edouttime": {
#                     "sdtype": "datetime"
#                 },
#                 "has_chartevents_data": {
#                     "sdtype": "numerical"
#                 }
#             }
#         },
#         "patients": {
#             "columns": {
#                 "subject_id": {
#                     "sdtype": "numerical"
#                 },
#                 "gender": {
#                     "sdtype": "categorical"
#                 },
#                 "dob": {
#                     "sdtype": "datetime"
#                 },
#                 "dod_hosp": {
#                     "sdtype": "datetime"
#                 },
#                 "dod_ssn": {
#                     "sdtype": "datetime"
#                 }
#             }
#         }
#     },
#     "relationships": [],
#     "METADATA_SPEC_VERSION": "MULTI_TABLE_V1"
# }

# %%
metadata.update_column(
    table_name='admissions',
    column_name='subject_id',
    sdtype='id'
)

metadata.update_column(
    table_name='admissions',
    column_name='hadm_id',
    sdtype='id'
)

metadata.update_column(
    table_name='admissions',
    column_name='has_chartevents_data',
    sdtype='categorical'
)

# %%
metadata.update_column(
    table_name='patients',
    column_name='subject_id',
    sdtype='id'
)

# %% [markdown]
# ## Setting primary keys

# %%
metadata.set_primary_key(
    table_name='patients',
    column_name='subject_id'
)

metadata.set_primary_key(
    table_name='admissions',
    column_name='hadm_id'
)

# %% [markdown]
# ## Setting relationships

# %%
metadata.add_relationship(
    parent_table_name='patients',
    child_table_name='admissions',
    parent_primary_key='subject_id',
    child_foreign_key='subject_id'
)

# %%
metadata.validate()

# %%
metadata.visualize()

# %%
from sdv.multi_table import HMASynthesizer

synthesizer = HMASynthesizer(metadata)
synthesizer.validate(dataTest)

# %%
synthesizer.fit(dataTest)
synthetic_data = synthesizer.sample(scale=1)
# Out:
# Preprocess Tables: 100%|██████████| 2/2 [00:00<00:00, 15.90it/s]
# Learning relationships:
# (1/1) Tables 'patients' and 'admissions' ('subject_id'): 100%|██████████| 100/100 [00:04<00:00, 22.15it/s]
# Modeling Tables: 100%|██████████| 1/1 [00:04<00:00,  4.31s/it]

# %%
synthetic_data['patients'].head()
# Out:
#    subject_id gender        dob   dod_hosp    dod_ssn
# 0           0      F 1920-01-29        NaT 2150-08-04
# 1           1      F 1951-04-05        NaT 2165-07-12
# 2           2      F 1918-08-08        NaT        NaT
# 3           3      M 1963-06-23 2162-07-14        NaT
# 4           4      F 1914-10-26        NaT 2138-04-05

# %%
synthetic_data['admissions']
# Out:
#      subject_id  hadm_id           admittime           dischtime  deathtime  \
# 0             0        0 2126-05-13 08:47:59 2127-03-17 03:39:02        NaN
# 1             0        1 2126-05-19 01:22:16 2127-06-25 23:11:18        NaN
# 2             0        2 2126-05-24 16:16:48 2127-09-02 22:25:04        NaN
# 3             1        3 2187-02-15 20:17:47 2187-09-26 16:42:59        NaN
# 4             1        4 2187-02-14 15:23:29 2187-08-06 06:06:01        NaN
# ..          ...      ...                 ...                 ...        ...
# 368          98      368 2183-03-04 15:31:41 2180-09-16 11:15:51        NaN
# 369          98      369 2181-10-19 06:32:43 2182-08-26 06:05:45        NaN
# 370          99      370 2172-01-28 06:43:10 2172-06-20 22:46:50        NaN
# 371          99      371 2174-01-24 02:40:55 2172-03-24 21:26:23        NaN
# 372          99      372 2173-09-12 08:01:29 2172-02-19 03:38:16        NaN
#
#     admission_type         admission_location         discharge_location  \
# 0        EMERGENCY  TRANSFER FROM HOSP/EXTRAM  DISC-TRAN CANCER/CHLDRN H
# 1        EMERGENCY  TRANSFER FROM HOSP/EXTRAM  DISC-TRAN CANCER/CHLDRN H
# 2          NEWBORN  TRANSFER FROM HOSP/EXTRAM  DISC-TRAN CANCER/CHLDRN H
# 3          NEWBORN  TRANSFER FROM HOSP/EXTRAM    LONG TERM CARE HOSPITAL
# 4          NEWBORN  CLINIC REFERRAL/PREMATURE    LONG TERM CARE HOSPITAL
# ..             ...                        ...                        ...
# 368      EMERGENCY  PHYS REFERRAL/NORMAL DELI   DISCH-TRAN TO PSYCH HOSP
# 369      EMERGENCY  PHYS REFERRAL/NORMAL DELI   DISCH-TRAN TO PSYCH HOSP
# 370        NEWBORN  CLINIC REFERRAL/PREMATURE   REHAB/DISTINCT PART HOSP
# 371       ELECTIVE  CLINIC REFERRAL/PREMATURE   REHAB/DISTINCT PART HOSP
# 372        NEWBORN  CLINIC REFERRAL/PREMATURE   REHAB/DISTINCT PART HOSP
#
#       insurance language           religion marital_status  \
# 0      Medicare     FREN           CATHOLIC            NaN
# 1      Medicare     FREN           CATHOLIC            NaN
# 2       Private     FREN           CATHOLIC            NaN
# 3      Medicaid     CANT           CATHOLIC        MARRIED
# 4      Medicaid     CANT           CATHOLIC        MARRIED
# ..          ...      ...                ...            ...
# 368    Medicare      NaN  PROTESTANT QUAKER        MARRIED
# 369    Medicaid      NaN  PROTESTANT QUAKER        MARRIED
# 370  Government      NaN                NaN            NaN
# 371  Government      NaN                NaN            NaN
# 372  Government      NaN                NaN            NaN
#
#                           ethnicity           edregtime           edouttime  \
# 0                             WHITE 2148-07-26 17:49:58                 NaT
# 1                             WHITE 2151-06-21 19:16:32                 NaT
# 2                             WHITE 2149-05-23 00:54:51                 NaT
# 3    HISPANIC/LATINO - PUERTO RICAN                 NaT                 NaT
# 4    HISPANIC/LATINO - PUERTO RICAN                 NaT                 NaT
# ..                              ...                 ...                 ...
# 368                           WHITE 2157-06-05 09:48:24 2161-07-03 16:45:17
# 369                           WHITE                 NaT                 NaT
# 370          BLACK/AFRICAN AMERICAN                 NaT 2156-09-20 13:24:25
# 371          BLACK/AFRICAN AMERICAN 2157-08-13 01:33:50                 NaT
# 372          BLACK/AFRICAN AMERICAN                 NaT 2158-01-01 10:09:20
#
#      has_chartevents_data
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ..                    ...
# 368                     1
# 369                     1
# 370                     0
# 371                     0
# 372                     0
#
# [373 rows x 16 columns]
